# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low = -90.000,high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
coordinates = list(lats_lngs)

# %%
from citipy import citipy

# %%
#Get cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #Add unique cities to cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 791

# %%
import requests

# %%
from datetime import datetime

# %%
#get weather api
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >=50):
        set_count +=1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url+"&q="+city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing record{record_count} of set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City" : city.title(),
                         "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
        
    except:
        print("City not found... Skipping")
        pass 
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record1 of set 1 | victoria
# Processing record2 of set 1 | busselton
# Processing record3 of set 1 | atikokan
# Processing record4 of set 1 | cidreira
# Processing record5 of set 1 | albany
# Processing record6 of set 1 | puerto ayora
# Processing record7 of set 1 | fairbanks
# Processing record8 of set 1 | ibipeba
# Processing record9 of set 1 | ilulissat
# Processing record10 of set 1 | ushuaia
# Processing record11 of set 1 | saint-raymond
# Processing record12 of set 1 | novobelokatay
# Processing record13 of set 1 | kodiak
# Processing record14 of set 1 | vranjska banja
# Processing record15 of set 1 | mandalgovi
# Processing record16 of set 1 | kamenka
# Processing record17 of set 1 | broome
# Processing record18 of set 1 | severo-kurilsk
# Processing record19 of set 1 | rikitea
# Processing record20 of set 1 | mataura
# Processing record21 of set 1 | clyde river
# Processing record22 of set 1 | dikson
# Processing record23 of set 1 | riyadh
# Processing record24 of set 1 | san cristobal
# Processing record25 of set 1 | college
# Processing record26 of set 1 | lompoc
# Processing record27 of set 1 | raudeberg
# Processing record28 of set 1 | mitu
# Processing record29 of set 1 | bredasdorp
# Processing record30 of set 1 | breyten
# Processing record31 of set 1 | tumannyy
# City not found... Skipping
# Processing record32 of set 1 | yerbogachen
# Processing record33 of set 1 | neiafu
# Processing record34 of set 1 | treinta y tres
# Processing record35 of set 1 | darnah
# Processing record36 of set 1 | cape town
# Processing record37 of set 1 | kapaa
# Processing record38 of set 1 | arraial do cabo
# Processing record39 of set 1 | novoanninskiy
# Processing record40 of set 1 | hobart
# Processing record41 of set 1 | hermanus
# Processing record42 of set 1 | burica
# City not found... Skipping
# Processing record43 of set 1 | zilair
# Processing record44 of set 1 | port macquarie
# Processing record45 of set 1 | coahuayana
# Processing record46 of set 1 | kirakira
# Processing record47 of set 1 | bambous virieux
# Processing record48 of set 1 | bluff
# Processing record49 of set 1 | baykit
# Processing record50 of set 1 | new norfolk
# Processing record1 of set 2 | caravelas
# Processing record2 of set 2 | hasaki
# Processing record3 of set 2 | puerto quijarro
# Processing record4 of set 2 | vaini
# Processing record5 of set 2 | arrifes
# Processing record6 of set 2 | sibolga
# Processing record7 of set 2 | codrington
# Processing record8 of set 2 | kumano
# Processing record9 of set 2 | bar harbor
# Processing record10 of set 2 | taolanaro
# City not found... Skipping
# Processing record11 of set 2 | saskylakh
# Processing record12 of set 2 | butaritari
# Processing record13 of set 2 | estelle
# Processing record14 of set 2 | port alfred
# Processing record15 of set 2 | toliary
# City not found... Skipping
# Processing record16 of set 2 | horodnytsya
# Processing record17 of set 2 | chuy
# Processing record18 of set 2 | san quintin
# Processing record19 of set 2 | ust-tsilma
# Processing record20 of set 2 | karkaralinsk
# City not found... Skipping
# Processing record21 of set 2 | atuona
# Processing record22 of set 2 | mocambique
# City not found... Skipping
# Processing record23 of set 2 | waterfoot
# Processing record24 of set 2 | yellowknife
# Processing record25 of set 2 | itarema
# Processing record26 of set 2 | axim
# Processing record27 of set 2 | ketchikan
# Processing record28 of set 2 | semey
# Processing record29 of set 2 | nantucket
# Processing record30 of set 2 | sao joao da barra
# Processing record31 of set 2 | oktyabrskiy
# Processing record32 of set 2 | sola
# Processing record33 of set 2 | joutseno
# Processing record34 of set 2 | mar del plata
# Processing record35 of set 2 | punta arenas
# Processing record36 of set 2 | tiksi
# Processing record37 of set 2 | ustye
# Processing record38 of set 2 | harsud
# Processing record39 of set 2 | belushya guba
# City not found... Skipping
# Processing record40 of set 2 | svetlogorsk
# Processing record41 of set 2 | dolbeau
# City not found... Skipping
# Processing record42 of set 2 | nikolskoye
# Processing record43 of set 2 | kasempa
# Processing record44 of set 2 | grand river south east
# City not found... Skipping
# Processing record45 of set 2 | santa rosa
# Processing record46 of set 2 | cabo san lucas
# Processing record47 of set 2 | saint george
# Processing record48 of set 2 | tibati
# Processing record49 of set 2 | batticaloa
# Processing record50 of set 2 | ribeira grande
# Processing record1 of set 3 | makakilo city
# Processing record2 of set 3 | thompson
# Processing record3 of set 3 | great yarmouth
# Processing record4 of set 3 | nevelsk
# Processing record5 of set 3 | betsiamites
# Processing record6 of set 3 | vardo
# Processing record7 of set 3 | hitachi
# Processing record8 of set 3 | port lincoln
# Processing record9 of set 3 | rawson
# Processing record10 of set 3 | ust-nera
# Processing record11 of set 3 | castro
# Processing record12 of set 3 | noumea
# Processing record13 of set 3 | umm lajj
# Processing record14 of set 3 | urucara
# Processing record15 of set 3 | esmeraldas
# Processing record16 of set 3 | markdale
# Processing record17 of set 3 | lavrentiya
# Processing record18 of set 3 | east london
# Processing record19 of set 3 | avarua
# Processing record20 of set 3 | mindelo
# Processing record21 of set 3 | taunggyi
# Processing record22 of set 3 | kabompo
# Processing record23 of set 3 | chagda
# City not found... Skipping
# Processing record24 of set 3 | obihiro
# Processing record25 of set 3 | airai
# Processing record26 of set 3 | san policarpo
# Processing record27 of set 3 | tessalit
# Processing record28 of set 3 | kapit
# Processing record29 of set 3 | cherskiy
# Processing record30 of set 3 | dunedin
# Processing record31 of set 3 | swellendam
# Processing record32 of set 3 | paamiut
# Processing record33 of set 3 | illoqqortoormiut
# City not found... Skipping
# Processing record34 of set 3 | soyo
# Processing record35 of set 3 | isangel
# Processing record36 of set 3 | iracoubo
# Processing record37 of set 3 | bowen
# Processing record38 of set 3 | hurricane
# Processing record39 of set 3 | tecoanapa
# Processing record40 of set 3 | konosha
# Processing record41 of set 3 | paracatu
# Processing record42 of set 3 | georgetown
# Processing record43 of set 3 | kaeo
# Processing record44 of set 3 | roebourne
# Processing record45 of set 3 | jamestown
# Processing record46 of set 3 | charters towers
# Processing record47 of set 3 | kruisfontein
# Processing record48 of set 3 | saint-philippe
# Processing record49 of set 3 | naze
# Processing record50 of set 3 | warrington
# Processing record1 of set 4 | kabanjahe
# Processing record2 of set 4 | carutapera
# Processing record3 of set 4 | felidhoo
# City not found... Skipping
# Processing record4 of set 4 | sentyabrskiy
# City not found... Skipping
# Processing record5 of set 4 | port elizabeth
# Processing record6 of set 4 | araouane
# Processing record7 of set 4 | panorama
# Processing record8 of set 4 | salalah
# Processing record9 of set 4 | itanhaem
# Processing record10 of set 4 | urusha
# Processing record11 of set 4 | balakhninskiy
# Processing record12 of set 4 | lasa
# Processing record13 of set 4 | saldanha
# Processing record14 of set 4 | norman wells
# Processing record15 of set 4 | kuche
# City not found... Skipping
# Processing record16 of set 4 | hilo
# Processing record17 of set 4 | havre
# Processing record18 of set 4 | khatanga
# Processing record19 of set 4 | fortuna
# Processing record20 of set 4 | zanatepec
# City not found... Skipping
# Processing record21 of set 4 | taoudenni
# Processing record22 of set 4 | toora-khem
# Processing record23 of set 4 | sao filipe
# Processing record24 of set 4 | cayeli
# Processing record25 of set 4 | laguna
# Processing record26 of set 4 | hithadhoo
# Processing record27 of set 4 | ipswich
# Processing record28 of set 4 | brightwater
# Processing record29 of set 4 | huarmey
# Processing record30 of set 4 | tuktoyaktuk
# Processing record31 of set 4 | turi
# Processing record32 of set 4 | pinawa
# Processing record33 of set 4 | roald
# Processing record34 of set 4 | chokurdakh
# Processing record35 of set 4 | vestmannaeyjar
# Processing record36 of set 4 | kavaratti
# Processing record37 of set 4 | marcona
# City not found... Skipping
# Processing record38 of set 4 | yunjinghong
# City not found... Skipping
# Processing record39 of set 4 | odweyne
# Processing record40 of set 4 | vangaindrano
# Processing record41 of set 4 | saleaula
# City not found... Skipping
# Processing record42 of set 4 | hofn
# Processing record43 of set 4 | santa lucia
# Processing record44 of set 4 | bengkulu
# Processing record45 of set 4 | samarai
# Processing record46 of set 4 | tuatapere
# Processing record47 of set 4 | ponta do sol
# Processing record48 of set 4 | vaitupu
# City not found... Skipping
# Processing record49 of set 4 | makanya
# Processing record50 of set 4 | basoko
# Processing record1 of set 5 | faanui
# Processing record2 of set 5 | stephenville
# Processing record3 of set 5 | sitka
# Processing record4 of set 5 | lebu
# Processing record5 of set 5 | alice springs
# Processing record6 of set 5 | nome
# Processing record7 of set 5 | kaitangata
# Processing record8 of set 5 | wonthaggi
# Processing record9 of set 5 | tarasovskiy
# Processing record10 of set 5 | ostrovnoy
# Processing record11 of set 5 | bethel
# Processing record12 of set 5 | amapa
# Processing record13 of set 5 | oriximina
# Processing record14 of set 5 | gusau
# Processing record15 of set 5 | samusu
# City not found... Skipping
# Processing record16 of set 5 | barrow
# Processing record17 of set 5 | hualmay
# Processing record18 of set 5 | mazara del vallo
# Processing record19 of set 5 | leningradskiy
# Processing record20 of set 5 | innisfail
# Processing record21 of set 5 | balkanabat
# Processing record22 of set 5 | lamu
# Processing record23 of set 5 | gandajika
# Processing record24 of set 5 | nyurba
# Processing record25 of set 5 | saint-francois
# Processing record26 of set 5 | krasnoselkup
# Processing record27 of set 5 | san carlos de bariloche
# Processing record28 of set 5 | nur
# Processing record29 of set 5 | carbonia
# Processing record30 of set 5 | rincon
# Processing record31 of set 5 | batemans bay
# Processing record32 of set 5 | likhoslavl
# Processing record33 of set 5 | langham
# Processing record34 of set 5 | bam
# Processing record35 of set 5 | la ronge
# Processing record36 of set 5 | iqaluit
# Processing record37 of set 5 | yokadouma
# Processing record38 of set 5 | alofi
# Processing record39 of set 5 | cockburn town
# Processing record40 of set 5 | kahului
# Processing record41 of set 5 | williams lake
# Processing record42 of set 5 | miramar
# Processing record43 of set 5 | attawapiskat
# City not found... Skipping
# Processing record44 of set 5 | buala
# Processing record45 of set 5 | sao miguel do araguaia
# Processing record46 of set 5 | rach gia
# Processing record47 of set 5 | kaihua
# Processing record48 of set 5 | tiznit
# Processing record49 of set 5 | mongoumba
# Processing record50 of set 5 | provideniya
# Processing record1 of set 6 | marawi
# Processing record2 of set 6 | shimoda
# Processing record3 of set 6 | mehamn
# Processing record4 of set 6 | charlottetown
# Processing record5 of set 6 | talnakh
# Processing record6 of set 6 | bandarbeyla
# Processing record7 of set 6 | puerto carreno
# Processing record8 of set 6 | labutta
# City not found... Skipping
# Processing record9 of set 6 | cayenne
# Processing record10 of set 6 | banes
# Processing record11 of set 6 | jambi
# Processing record12 of set 6 | lluta
# Processing record13 of set 6 | adrar
# Processing record14 of set 6 | tual
# Processing record15 of set 6 | atar
# Processing record16 of set 6 | kavieng
# Processing record17 of set 6 | raga
# Processing record18 of set 6 | inhambane
# Processing record19 of set 6 | bull savanna
# Processing record20 of set 6 | lorengau
# Processing record21 of set 6 | outlook
# Processing record22 of set 6 | ancud
# Processing record23 of set 6 | westport
# Processing record24 of set 6 | nadym
# Processing record25 of set 6 | fort nelson
# Processing record26 of set 6 | nakapiripirit
# Processing record27 of set 6 | pacific grove
# Processing record28 of set 6 | torbay
# Processing record29 of set 6 | okha
# Processing record30 of set 6 | popondetta
# Processing record31 of set 6 | santa cruz
# Processing record32 of set 6 | cape canaveral
# Processing record33 of set 6 | souillac
# Processing record34 of set 6 | villanueva de la serena
# Processing record35 of set 6 | nizhneyansk
# City not found... Skipping
# Processing record36 of set 6 | san andres
# Processing record37 of set 6 | concepcion de maria
# City not found... Skipping
# Processing record38 of set 6 | upernavik
# Processing record39 of set 6 | mezen
# Processing record40 of set 6 | ranong
# Processing record41 of set 6 | baoding
# Processing record42 of set 6 | guerrero negro
# Processing record43 of set 6 | mehran
# Processing record44 of set 6 | san matias
# Processing record45 of set 6 | amderma
# City not found... Skipping
# Processing record46 of set 6 | galgani
# City not found... Skipping
# Processing record47 of set 6 | ishigaki
# Processing record48 of set 6 | albion
# Processing record49 of set 6 | onega
# Processing record50 of set 6 | sehithwa
# Processing record1 of set 7 | meulaboh
# Processing record2 of set 7 | humboldt
# Processing record3 of set 7 | kamyshla
# Processing record4 of set 7 | mana
# Processing record5 of set 7 | pinotepa nacional
# Processing record6 of set 7 | los llanos de aridane
# Processing record7 of set 7 | khash
# Processing record8 of set 7 | bolungarvik
# City not found... Skipping
# Processing record9 of set 7 | malwan
# City not found... Skipping
# Processing record10 of set 7 | seoul
# Processing record11 of set 7 | bakchar
# Processing record12 of set 7 | yulara
# Processing record13 of set 7 | port moresby
# Processing record14 of set 7 | umm kaddadah
# Processing record15 of set 7 | aklavik
# Processing record16 of set 7 | saint-augustin
# Processing record17 of set 7 | rio gallegos
# Processing record18 of set 7 | pilar
# Processing record19 of set 7 | tasiilaq
# Processing record20 of set 7 | nakonde
# Processing record21 of set 7 | qaanaaq
# Processing record22 of set 7 | jabiru
# City not found... Skipping
# Processing record23 of set 7 | asau
# Processing record24 of set 7 | dillon
# Processing record25 of set 7 | avera
# Processing record26 of set 7 | barentsburg
# City not found... Skipping
# Processing record27 of set 7 | port-cartier
# Processing record28 of set 7 | waipawa
# Processing record29 of set 7 | grindavik
# Processing record30 of set 7 | albert
# Processing record31 of set 7 | venezuela
# Processing record32 of set 7 | yomitan
# City not found... Skipping
# Processing record33 of set 7 | palmer
# Processing record34 of set 7 | safranbolu
# Processing record35 of set 7 | paradwip
# City not found... Skipping
# Processing record36 of set 7 | bahia honda
# Processing record37 of set 7 | mahebourg
# Processing record38 of set 7 | yumen
# Processing record39 of set 7 | hidalgotitlan
# Processing record40 of set 7 | touros
# Processing record41 of set 7 | kuna
# Processing record42 of set 7 | bodden town
# Processing record43 of set 7 | constitucion
# Processing record44 of set 7 | tsihombe
# City not found... Skipping
# Processing record45 of set 7 | ugljevik
# Processing record46 of set 7 | mys shmidta
# City not found... Skipping
# Processing record47 of set 7 | abay
# Processing record48 of set 7 | kudahuvadhoo
# Processing record49 of set 7 | sandwick
# Processing record50 of set 7 | bac giang
# Processing record1 of set 8 | esperance
# Processing record2 of set 8 | sosnovo-ozerskoye
# Processing record3 of set 8 | carnarvon
# Processing record4 of set 8 | chake chake
# Processing record5 of set 8 | rocha
# Processing record6 of set 8 | cap malheureux
# Processing record7 of set 8 | baiao
# Processing record8 of set 8 | monrovia
# Processing record9 of set 8 | luderitz
# Processing record10 of set 8 | havoysund
# Processing record11 of set 8 | aflu
# City not found... Skipping
# Processing record12 of set 8 | olinda
# Processing record13 of set 8 | lata
# Processing record14 of set 8 | klaksvik
# Processing record15 of set 8 | canmore
# Processing record16 of set 8 | gavle
# Processing record17 of set 8 | palaikastron
# Processing record18 of set 8 | minab
# Processing record19 of set 8 | pochutla
# Processing record20 of set 8 | lithakia
# Processing record21 of set 8 | labuhan
# Processing record22 of set 8 | san patricio
# Processing record23 of set 8 | malindi
# Processing record24 of set 8 | volga
# Processing record25 of set 8 | lagoa
# Processing record26 of set 8 | murgab
# Processing record27 of set 8 | gat
# Processing record28 of set 8 | mayor pablo lagerenza
# Processing record29 of set 8 | altay
# Processing record30 of set 8 | sebinkarahisar
# Processing record31 of set 8 | galiwinku
# City not found... Skipping
# Processing record32 of set 8 | coihaique
# Processing record33 of set 8 | griffith
# Processing record34 of set 8 | cajuru
# Processing record35 of set 8 | baghdad
# Processing record36 of set 8 | khonuu
# City not found... Skipping
# Processing record37 of set 8 | altamira
# Processing record38 of set 8 | marsh harbour
# Processing record39 of set 8 | honiara
# Processing record40 of set 8 | saint-leu
# Processing record41 of set 8 | plettenberg bay
# Processing record42 of set 8 | marzuq
# Processing record43 of set 8 | xixiang
# Processing record44 of set 8 | kupang
# Processing record45 of set 8 | sompeta
# Processing record46 of set 8 | korla
# Processing record47 of set 8 | te anau
# Processing record48 of set 8 | husavik
# Processing record49 of set 8 | santarem
# Processing record50 of set 8 | chapais
# Processing record1 of set 9 | lazaro cardenas
# Processing record2 of set 9 | bambanglipuro
# Processing record3 of set 9 | diego de almagro
# Processing record4 of set 9 | longlac
# City not found... Skipping
# Processing record5 of set 9 | ilebo
# Processing record6 of set 9 | araucaria
# Processing record7 of set 9 | port-gentil
# Processing record8 of set 9 | kamina
# Processing record9 of set 9 | jacmel
# Processing record10 of set 9 | vila
# Processing record11 of set 9 | mapiri
# Processing record12 of set 9 | calancuasan
# City not found... Skipping
# Processing record13 of set 9 | aitape
# Processing record14 of set 9 | koulikoro
# Processing record15 of set 9 | tres passos
# Processing record16 of set 9 | hauterive
# Processing record17 of set 9 | machachi
# Processing record18 of set 9 | vao
# Processing record19 of set 9 | auki
# Processing record20 of set 9 | walvis bay
# Processing record21 of set 9 | kodino
# Processing record22 of set 9 | puro
# Processing record23 of set 9 | yambio
# Processing record24 of set 9 | longyearbyen
# Processing record25 of set 9 | goure
# Processing record26 of set 9 | tansen
# Processing record27 of set 9 | trincomalee
# Processing record28 of set 9 | gondar
# Processing record29 of set 9 | aksay
# Processing record30 of set 9 | aginskoye
# Processing record31 of set 9 | gazojak
# Processing record32 of set 9 | katsuura
# Processing record33 of set 9 | burnie
# Processing record34 of set 9 | nuuk
# Processing record35 of set 9 | ashland
# Processing record36 of set 9 | cedar city
# Processing record37 of set 9 | kamenskoye
# City not found... Skipping
# Processing record38 of set 9 | atherton
# Processing record39 of set 9 | montepuez
# Processing record40 of set 9 | bilma
# Processing record41 of set 9 | salihorsk
# Processing record42 of set 9 | stromness
# Processing record43 of set 9 | halalo
# City not found... Skipping
# Processing record44 of set 9 | kabare
# Processing record45 of set 9 | tambopata
# Processing record46 of set 9 | yatou
# Processing record47 of set 9 | toyooka
# Processing record48 of set 9 | maunabo
# Processing record49 of set 9 | tolaga bay
# Processing record50 of set 9 | nemuro
# Processing record1 of set 10 | kolondieba
# Processing record2 of set 10 | iquitos
# Processing record3 of set 10 | nezhinka
# Processing record4 of set 10 | smolenka
# Processing record5 of set 10 | key west
# Processing record6 of set 10 | pundaguitan
# Processing record7 of set 10 | gazanjyk
# Processing record8 of set 10 | pecos
# Processing record9 of set 10 | bubaque
# Processing record10 of set 10 | pisco
# Processing record11 of set 10 | saint-denis
# Processing record12 of set 10 | yongchang
# Processing record13 of set 10 | lodwar
# Processing record14 of set 10 | vanimo
# Processing record15 of set 10 | waingapu
# Processing record16 of set 10 | saint-pierre
# Processing record17 of set 10 | barranca
# Processing record18 of set 10 | kutum
# Processing record19 of set 10 | teya
# Processing record20 of set 10 | hopkinton
# Processing record21 of set 10 | jacareacanga
# Processing record22 of set 10 | turayf
# Processing record23 of set 10 | verkhoyansk
# Processing record24 of set 10 | wloclawek
# Processing record25 of set 10 | kirensk
# Processing record26 of set 10 | bagdarin
# Processing record27 of set 10 | isiro
# Processing record28 of set 10 | rungata
# City not found... Skipping
# Processing record29 of set 10 | artesia
# Processing record30 of set 10 | sorvag
# City not found... Skipping
# Processing record31 of set 10 | aquiraz
# Processing record32 of set 10 | wardha
# Processing record33 of set 10 | berlevag
# Processing record34 of set 10 | babol
# Processing record35 of set 10 | palabuhanratu
# City not found... Skipping
# Processing record36 of set 10 | gulfport
# Processing record37 of set 10 | sisimiut
# Processing record38 of set 10 | kralendijk
# Processing record39 of set 10 | santa cruz de la palma
# Processing record40 of set 10 | barcelona
# Processing record41 of set 10 | sofiysk
# City not found... Skipping
# Processing record42 of set 10 | atasu
# Processing record43 of set 10 | tezu
# Processing record44 of set 10 | umzimvubu
# City not found... Skipping
# Processing record45 of set 10 | gizo
# Processing record46 of set 10 | laiya
# Processing record47 of set 10 | oranjemund
# Processing record48 of set 10 | emerald
# Processing record49 of set 10 | igaracu do tiete
# Processing record50 of set 10 | puerto colombia
# Processing record1 of set 11 | olafsvik
# Processing record2 of set 11 | marv dasht
# City not found... Skipping
# Processing record3 of set 11 | ulladulla
# Processing record4 of set 11 | mamallapuram
# Processing record5 of set 11 | garissa
# Processing record6 of set 11 | nanortalik
# Processing record7 of set 11 | vathi
# Processing record8 of set 11 | antsohihy
# Processing record9 of set 11 | safwah
# City not found... Skipping
# Processing record10 of set 11 | anton lizardo
# Processing record11 of set 11 | panaba
# Processing record12 of set 11 | vila franca do campo
# Processing record13 of set 11 | narsaq
# Processing record14 of set 11 | mount gambier
# Processing record15 of set 11 | matara
# Processing record16 of set 11 | palauig
# Processing record17 of set 11 | mount isa
# Processing record18 of set 11 | kiama
# Processing record19 of set 11 | coquimbo
# Processing record20 of set 11 | myitkyina
# Processing record21 of set 11 | henties bay
# Processing record22 of set 11 | havre-saint-pierre
# Processing record23 of set 11 | comonfort
# Processing record24 of set 11 | kangaatsiaq
# Processing record25 of set 11 | awbari
# Processing record26 of set 11 | ayia marina
# Processing record27 of set 11 | beringovskiy
# Processing record28 of set 11 | cananeia
# Processing record29 of set 11 | astorga
# Processing record30 of set 11 | eyl
# Processing record31 of set 11 | miraflores
# Processing record32 of set 11 | yamada
# Processing record33 of set 11 | nokaneng
# Processing record34 of set 11 | kousseri
# Processing record35 of set 11 | viedma
# Processing record36 of set 11 | zabaykalsk
# Processing record37 of set 11 | aktash
# Processing record38 of set 11 | mudyuga
# City not found... Skipping
# Processing record39 of set 11 | sorland
# Processing record40 of set 11 | bandarban
# Processing record41 of set 11 | cata
# Processing record42 of set 11 | green river
# Processing record43 of set 11 | vostok
# Processing record44 of set 11 | praya
# Processing record45 of set 11 | taungdwingyi
# Processing record46 of set 11 | nautla
# Processing record47 of set 11 | shibarghan
# City not found... Skipping
# Processing record48 of set 11 | antalaha
# Processing record49 of set 11 | hobyo
# Processing record50 of set 11 | acarau
# Processing record1 of set 12 | mampong
# Processing record2 of set 12 | bathsheba
# Processing record3 of set 12 | san luis
# Processing record4 of set 12 | acapulco
# Processing record5 of set 12 | vagay
# Processing record6 of set 12 | pokosnoye
# Processing record7 of set 12 | general cepeda
# Processing record8 of set 12 | ciudad guayana
# Processing record9 of set 12 | sioux lookout
# Processing record10 of set 12 | abrau-dyurso
# Processing record11 of set 12 | candawaga
# City not found... Skipping
# Processing record12 of set 12 | abashiri
# Processing record13 of set 12 | ksenyevka
# City not found... Skipping
# Processing record14 of set 12 | gairo
# Processing record15 of set 12 | macaboboni
# City not found... Skipping
# Processing record16 of set 12 | cuiluan
# Processing record17 of set 12 | cabedelo
# Processing record18 of set 12 | vila velha
# Processing record19 of set 12 | comodoro rivadavia
# Processing record20 of set 12 | payo
# Processing record21 of set 12 | bijie
# Processing record22 of set 12 | ellisras
# Processing record23 of set 12 | mushie
# Processing record24 of set 12 | kungurtug
# Processing record25 of set 12 | matsubase
# Processing record26 of set 12 | mugur-aksy
# Processing record27 of set 12 | nata
# Processing record28 of set 12 | mizdah
# Processing record29 of set 12 | corning
# Processing record30 of set 12 | mahibadhoo
# Processing record31 of set 12 | jamay
# Processing record32 of set 12 | kyra
# Processing record33 of set 12 | dingle
# Processing record34 of set 12 | ucluelet
# Processing record35 of set 12 | sangar
# Processing record36 of set 12 | ahero
# Processing record37 of set 12 | camopi
# Processing record38 of set 12 | loralai
# Processing record39 of set 12 | oleksandrivka
# Processing record40 of set 12 | pinos
# Processing record41 of set 12 | tshikapa
# Processing record42 of set 12 | iralaya
# Processing record43 of set 12 | chaa-khol
# City not found... Skipping
# Processing record44 of set 12 | pevek
# Processing record45 of set 12 | notse
# Processing record46 of set 12 | millinocket
# Processing record47 of set 12 | ust-ishim
# Processing record48 of set 12 | calvinia
# Processing record49 of set 12 | kudat
# Processing record50 of set 12 | najran
# Processing record1 of set 13 | rincon de la victoria
# Processing record2 of set 13 | evensk
# Processing record3 of set 13 | petropavlovsk-kamchatskiy
# Processing record4 of set 13 | solovetskiy
# City not found... Skipping
# Processing record5 of set 13 | brandon
# Processing record6 of set 13 | santa isabel
# Processing record7 of set 13 | jiazi
# Processing record8 of set 13 | yelbarga
# Processing record9 of set 13 | pangkalanbuun
# Processing record10 of set 13 | quatre cocos
# Processing record11 of set 13 | san francisco
# Processing record12 of set 13 | mayna
# Processing record13 of set 13 | dwarka
# Processing record14 of set 13 | mbarara
# Processing record15 of set 13 | poya
# Processing record16 of set 13 | kainantu
# Processing record17 of set 13 | tihuatlan
# Processing record18 of set 13 | bitung
# Processing record19 of set 13 | banda aceh
# Processing record20 of set 13 | ossora
# Processing record21 of set 13 | magadan
# Processing record22 of set 13 | torquay
# Processing record23 of set 13 | sayat
# Processing record24 of set 13 | scottsburgh
# City not found... Skipping
# Processing record25 of set 13 | severobaykalsk
# Processing record26 of set 13 | buraydah
# Processing record27 of set 13 | mayumba
# Processing record28 of set 13 | srednekolymsk
# Processing record29 of set 13 | saint anthony
# Processing record30 of set 13 | konstantinovka
# Processing record31 of set 13 | khandyga
# Processing record32 of set 13 | muroto
# Processing record33 of set 13 | veydelevka
# Processing record34 of set 13 | manzhouli
# Processing record35 of set 13 | mersing
# Processing record36 of set 13 | chama
# Processing record37 of set 13 | mtambile
# Processing record38 of set 13 | salvador
# Processing record39 of set 13 | asfi
# Processing record40 of set 13 | bilibino
# Processing record41 of set 13 | aswan
# Processing record42 of set 13 | uga
# Processing record43 of set 13 | khasan
# Processing record44 of set 13 | hrymayliv
# Processing record45 of set 13 | vagur
# Processing record46 of set 13 | gikongoro
# Processing record47 of set 13 | sidhi
# Processing record48 of set 13 | tefe
# Processing record49 of set 13 | jalapa
# Processing record50 of set 13 | hay river
# Processing record1 of set 14 | billings
# Processing record2 of set 14 | oranjestad
# Processing record3 of set 14 | tomaszow lubelski
# Processing record4 of set 14 | borovoy
# Processing record5 of set 14 | tabiauea
# City not found... Skipping
# Processing record6 of set 14 | masumbwe
# Processing record7 of set 14 | broken hill
# Processing record8 of set 14 | port hardy
# Processing record9 of set 14 | buariki
# City not found... Skipping
# Processing record10 of set 14 | kalmunai
# Processing record11 of set 14 | qeshm
# Processing record12 of set 14 | west bay
# Processing record13 of set 14 | zabol
# Processing record14 of set 14 | halifax
# Processing record15 of set 14 | harboore
# Processing record16 of set 14 | lagoa formosa
# Processing record17 of set 14 | san juan
# Processing record18 of set 14 | chicopee
# Processing record19 of set 14 | flinders
# Processing record20 of set 14 | roma
# Processing record21 of set 14 | the valley
# Processing record22 of set 14 | qaqortoq
# Processing record23 of set 14 | chateauroux
# Processing record24 of set 14 | moroni
# Processing record25 of set 14 | aykhal
# Processing record26 of set 14 | lintangan
# Processing record27 of set 14 | tarakan
# Processing record28 of set 14 | belaya gora
# Processing record29 of set 14 | colares
# Processing record30 of set 14 | bushehr
# Processing record31 of set 14 | mentok
# City not found... Skipping
# Processing record32 of set 14 | whitianga
# Processing record33 of set 14 | avon park
# Processing record34 of set 14 | lukulu
# Processing record35 of set 14 | oktyabrskoye
# Processing record36 of set 14 | porteirinha
# Processing record37 of set 14 | kaputa
# Processing record38 of set 14 | tautira
# Processing record39 of set 14 | pangnirtung
# Processing record40 of set 14 | karratha
# Processing record41 of set 14 | luwuk
# Processing record42 of set 14 | babu
# Processing record43 of set 14 | blythe
# Processing record44 of set 14 | hervey bay
# Processing record45 of set 14 | chifeng
# Processing record46 of set 14 | mutare
# Processing record47 of set 14 | komsomolskiy
# Processing record48 of set 14 | haibowan
# City not found... Skipping
# Processing record49 of set 14 | woodward
# Processing record50 of set 14 | pasni
# Processing record1 of set 15 | haizhou
# Processing record2 of set 15 | along
# Processing record3 of set 15 | ust-maya
# Processing record4 of set 15 | demba
# Processing record5 of set 15 | det udom
# Processing record6 of set 15 | kenai
# Processing record7 of set 15 | araguacu
# Processing record8 of set 15 | artyk
# City not found... Skipping
# Processing record9 of set 15 | half moon bay
# Processing record10 of set 15 | mogadouro
# Processing record11 of set 15 | bismarck
# Processing record12 of set 15 | akdepe
# Processing record13 of set 15 | boca do acre
# Processing record14 of set 15 | jacobabad
# Processing record15 of set 15 | ngukurr
# City not found... Skipping
# Processing record16 of set 15 | nouadhibou
# Processing record17 of set 15 | ardakan
# Processing record18 of set 15 | humberto de campos
# Processing record19 of set 15 | pontes e lacerda
# Processing record20 of set 15 | tunduru
# City not found... Skipping
# Processing record21 of set 15 | mnogovershinnyy
# Processing record22 of set 15 | gurupa
# Processing record23 of set 15 | warqla
# City not found... Skipping
# Processing record24 of set 15 | mariara
# Processing record25 of set 15 | emba
# Processing record26 of set 15 | linqing
# Processing record27 of set 15 | kununurra
# Processing record28 of set 15 | moron
# Processing record29 of set 15 | beaverlodge
# Processing record30 of set 15 | preobrazhenskaya
# City not found... Skipping
# Processing record31 of set 15 | guiyang
# Processing record32 of set 15 | lianzhou
# Processing record33 of set 15 | faya
# Processing record34 of set 15 | ilo
# Processing record35 of set 15 | labrea
# Processing record36 of set 15 | zelenogorskiy
# Processing record37 of set 15 | amarante do maranhao
# Processing record38 of set 15 | general bravo
# Processing record39 of set 15 | pandan
# Processing record40 of set 15 | geresk
# City not found... Skipping
# Processing record41 of set 15 | dovers
# Processing record42 of set 15 | ukiah
# Processing record43 of set 15 | ippy
# Processing record44 of set 15 | kadykchan
# City not found... Skipping
# Processing record45 of set 15 | makung
# City not found... Skipping
# Processing record46 of set 15 | alta floresta
# Processing record47 of set 15 | lokosovo
# Processing record48 of set 15 | tailai
# Processing record49 of set 15 | galle
# Processing record50 of set 15 | rio grande
# Processing record1 of set 16 | grand centre
# City not found... Skipping
# Processing record2 of set 16 | general roca
# Processing record3 of set 16 | basco
# Processing record4 of set 16 | tazovskiy
# Processing record5 of set 16 | naples
# Processing record6 of set 16 | kushmurun
# Processing record7 of set 16 | shahrud
# Processing record8 of set 16 | vohibinany
# Processing record9 of set 16 | yenagoa
# Processing record10 of set 16 | hovd
# Processing record11 of set 16 | sao jose da coroa grande
# Processing record12 of set 16 | harper
# Processing record13 of set 16 | la grande
# Processing record14 of set 16 | skibbereen
# Processing record15 of set 16 | xifeng
# Processing record16 of set 16 | odate
# Processing record17 of set 16 | waddan
# Processing record18 of set 16 | qabaqcol
# Processing record19 of set 16 | elizabeth city
# Processing record20 of set 16 | shingu
# Processing record21 of set 16 | maputo
# Processing record22 of set 16 | stornoway
# Processing record23 of set 16 | doume
# Processing record24 of set 16 | inongo
# Processing record25 of set 16 | brufut
# Processing record26 of set 16 | ellensburg
# Processing record27 of set 16 | zhenhai
# Processing record28 of set 16 | smithers
# Processing record29 of set 16 | mitsamiouli
# Processing record30 of set 16 | bertoua
# Processing record31 of set 16 | matehuala
# Processing record32 of set 16 | luang prabang
# Processing record33 of set 16 | alyangula
# Processing record34 of set 16 | dali
# Processing record35 of set 16 | caninde de sao francisco
# Processing record36 of set 16 | satinka
# Processing record37 of set 16 | bahia blanca
# Processing record38 of set 16 | pitmoaga
# Processing record39 of set 16 | sarkand
# Processing record40 of set 16 | dobroye
# Processing record41 of set 16 | dicabisagan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Victoria      HK  22.2855  114.1577     75.33        80          78
# 1     Busselton      AU -33.6500  115.3333     49.80        90          35
# 2      Atikokan      CA  48.7555  -91.6216     49.62        61         100
# 3      Cidreira      BR -30.1811  -50.2056     71.15        78          72
# 4        Albany      US  42.6001  -73.9662     57.94        93          99
# 5  Puerto Ayora      EC  -0.7393  -90.3518     72.79        79          71
# 6     Fairbanks      US  64.8378 -147.7164     27.10        89          20
# 7       Ibipeba      BR -11.6408  -42.0111     88.25        29          17
# 8     Ilulissat      GL  69.2167  -51.1000     30.94        88         100
# 9       Ushuaia      AR -54.8000  -68.3000     56.89        34          20
#
#    Wind Speed Current Description
# 0        5.01       broken clouds
# 1        6.87    scattered clouds
# 2        9.08     overcast clouds
# 3       22.97       broken clouds
# 4        7.99     overcast clouds
# 5        8.86       broken clouds
# 6        9.22          few clouds
# 7        7.52          few clouds
# 8        5.84     overcast clouds
# 9        3.29          few clouds

# %%
# Create the output file (CSV).
output_data_file = 'Weather_Database/WeatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = 'City_ID')
